# %% [markdown]
# <a href="https://colab.research.google.com/github/JBalbuenaG/proyecto_DL/blob/main/3_FER2013_VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Este script es similar al usando para entrenar el ResNet con la diferencia de que se carga el modelo pre-entrenado
#del VGG-16
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense, Flatten, Dropout
from tensorflow.keras.applications.vgg16 import VGG16 as PretrainedModel, preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path = '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train'
valid_path = '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/test'
train_image_files = glob(train_path +'/*/*.jpg')
valid_image_files = glob(valid_path +'/*/*.jpg')

# %%
folders = glob(train_path + '/*')
print(folders)
# Out:
# ['/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/0', '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/1', '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/2', '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/3', '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/4', '/content/drive/My Drive/Proyecto_DL/dataset_fer2013/train/5']

# %%
plt.imshow(image.load_img(np.random.choice(valid_image_files)))
plt.show()

# %%
IMAGE_SIZE = [200,200]
ptm = PretrainedModel(
    input_shape=IMAGE_SIZE+[3],
    weights='imagenet',
    include_top=False)

ptm.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
K = len(folders) 
x = Flatten()(ptm.output)

model = Model(inputs=ptm.input, outputs=x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# gen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# batch_size = 128

# train_generator = gen.flow_from_directory(
#     train_path,
#     target_size=IMAGE_SIZE,
#     batch_size=batch_size,
#     class_mode = 'sparse'
# )

# valid_generator = gen.flow_from_directory(
#     valid_path,
#     target_size=IMAGE_SIZE,
#     batch_size=batch_size,
#     class_mode = 'sparse'
# )
# Out:
# Found 21708 images belonging to 6 classes.
# Found 2982 images belonging to 6 classes.

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# N_train = len(train_image_files)
# N_valid = len(valid_image_files)

# feat = model.predict(np.random.random([1]+IMAGE_SIZE+[3]))
# D = feat.shape[1]

# X_train = np.zeros((N_train,D))
# Y_train = np.zeros(N_train)
# X_valid = np.zeros((N_valid,D))
# Y_valid = np.zeros(N_valid)

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# i = 0
# for x, y in train_generator:
#     features = model.predict(x)
  
#     sz = len(y)
#     X_train[i:i+sz]=features
#     Y_train[i:i+sz]=y

#     i += sz
#     if i%1280==0:
#         print(i)

#     if i>=N_train:
#         print('breaking now')
#         break

# print(i)
# Out:
# 1280
# 2560
# 3840
# 5120
# 6400
# 7680
# 8960
# 10240
# 11520
# 12800
# 14080
# 15360
# 16640
# 17920
# 19200
# 20480
# breaking now
# 21708

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# np.save('/content/drive/My Drive/Proyecto_DL/vectors/X_train_fer20132VGG.npy', X_train)
# np.save('/content/drive/My Drive/Proyecto_DL/vectors/Y_train_fer20132VGG.npy', Y_train)

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# i = 0
# for x, y in valid_generator:
#     features = model.predict(x)
  
#     sz = len(y) 
#     X_valid[i:i+sz]=features
#     Y_valid[i:i+sz]=y

#     i += sz
#     if i%1280==0:
#         print(i)

#     if i>=N_valid:
#         print('breaking now')
#         break

# print(i)
# Out:
# 1280
# 2560
# breaking now
# 2982

# %%
# # ACTIVAR SOLO LA PRIMERA VEZ
# np.save('/content/drive/My Drive/Proyecto_DL/vectors/X_valid_fer20132VGG.npy', X_valid)
# np.save('/content/drive/My Drive/Proyecto_DL/vectors/Y_valid_fer20132VGG.npy', Y_valid)

# %%
X_train = np.load('/content/drive/My Drive/Proyecto_DL/vectors/X_train_fer20132VGG.npy')
Y_train = np.load('/content/drive/My Drive/Proyecto_DL/vectors/Y_train_fer20132VGG.npy')
X_valid = np.load('/content/drive/My Drive/Proyecto_DL/vectors/X_valid_fer20132VGG.npy')
Y_valid = np.load('/content/drive/My Drive/Proyecto_DL/vectors/Y_valid_fer20132VGG.npy')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

import matplotlib.pyplot as plt
import seaborn as sns

#Definición para el calculo de metricas multi-clase
def calculo_metricas(CM, emociones):
    
    emocion = []
    TruPos = []
    FalPos = []
    FalNeg = []
    TruNeg = []
    acc = []
    prec = []
    recall = []
    f1 = []
    
    total = np.sum(CM)
    
    for i in range(len(emociones)):
       
        TP = CM[i][i]
        FP = sum(CM[:,i])-TP
        FN = sum(CM[i,:])-TP
        TN = total - TP-FN-FP
        a = (TP+TN)/(TP+TN+FN+FP)
        p = TP/(TP+FP)
        r = TP/(TP+FN)
        f = 2*(r*p)/(r+p)
        
        emocion.append(emociones[i])
        TruPos.append(TP)
        FalPos.append(FP)
        TruNeg.append(TN)
        acc.append(a)
        prec.append(p)
        recall.append(r)
        f1.append(f)
    
    metricas = pd.DataFrame()
    metricas['Emociones']=emocion
    metricas['Accuracy']=acc
    metricas['Precision']=prec
    metricas['Recall']=recall
    metricas['F1-Score']=f1
    
    return metricas

def graf_confusion_matrix(CM, emociones,emb):
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(CM,annot=True,fmt='',xticklabels=emociones,yticklabels=emociones, ax=ax, cmap='Blues');
    ax.set_title('Matriz de confusión '+emb);
    ax.set_xlabel('Valores Predecidos');
    ax.set_ylabel('Valores Verdaderos');
    
def graficar_historia_entrenamiento(log, metric='accuracy'):
    fig, axes = plt.subplots(1, 2, figsize=(14,4))
    ax1, ax2 = axes
    ax1.plot(log.history['loss'], label='train')
    ax1.plot(log.history['val_loss'], label='test')
    ax1.set_xlabel('epoch'); ax1.set_ylabel('loss')
    ax2.plot(log.history[metric], label='train')
    ax2.plot(log.history['val_'+metric], label='test')
    ax2.set_xlabel('epoch'); ax2.set_ylabel(metric)
    #ax2.set_ylim((0.0, 1.0))
    for ax in axes: ax.legend()

# %%
feat = model.predict(np.random.random([1]+IMAGE_SIZE+[3]))
D = feat.shape[1]

#Modelo de red neuronal para clasificación
#i = Input(shape=(D,))
#x = Dense(4096, activation='relu')(i)
#x = Dropout(0.2)(x)
#x = Dense(4096, activation='relu')(x)
#x = Dense(6, activation='softmax')(x)

#Modelo de red neuronal para clasificación multiclase
i = Input(shape=(D,))
x = Dense(1024, activation='relu')(i)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(6, activation='softmax')(x)

emo_model = Model(i ,x)

# entrenado con metrica 'accuracy' o 'tf.keras.metrics.sparse_categorical_accuracy'
emo_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics= tf.keras.metrics.sparse_categorical_accuracy
)

# %%
r = emo_model.fit(
    X_train, Y_train,
    batch_size=64,
    epochs=20,
    validation_data=(X_valid,Y_valid)
)
# Out:
# Epoch 1/20
# 340/340 [==============================] - 62s 180ms/step - loss: 7.2220 - sparse_categorical_accuracy: 0.3918 - val_loss: 1.1946 - val_sparse_categorical_accuracy: 0.5379
# Epoch 2/20
# 340/340 [==============================] - 61s 179ms/step - loss: 1.2046 - sparse_categorical_accuracy: 0.5411 - val_loss: 1.1738 - val_sparse_categorical_accuracy: 0.5339
# Epoch 3/20
# 340/340 [==============================] - 61s 180ms/step - loss: 1.0870 - sparse_categorical_accuracy: 0.5841 - val_loss: 1.1399 - val_sparse_categorical_accuracy: 0.5741
# Epoch 4/20
# 340/340 [==============================] - 61s 178ms/step - loss: 1.0146 - sparse_categorical_accuracy: 0.6188 - val_loss: 1.1146 - val_sparse_categorical_accuracy: 0.5795
# Epoch 5/20
# 340/340 [==============================] - 61s 180ms/step - loss: 0.9025 - sparse_categorical_accuracy: 0.6525 - val_loss: 1.1651 - val_sparse_categorical_accuracy: 0.5731
# Epoch 6/20
# 340/340 [==============================] - 61s 181ms/step - loss: 0.8332 - sparse_categorical_accuracy: 0.6815 - val_loss: 1.1389 - val_sparse_categorical_accuracy: 0.5848
# Epoch 7/20
# 340/340 [==============================] - 62s 182ms/step - loss: 0.7411 - sparse_categorical_accuracy: 0.7199 - val_loss: 1.1406 - val_sparse_categorical_accuracy: 0.5999
# Epoch 8/20
# 340/340 [==============================] - 62s 182ms/step - loss: 0.6970 - sparse_categorical_accuracy: 0.7334 - val_loss: 1.1734 - val_sparse_categorical_accuracy: 0.5983
# Epoch 9/20
# 340/340 [==============================] - 60s 176ms/step - loss: 0.6807 - sparse_categorical_accuracy: 0.7438 - val_loss: 1.2697 - val_sparse_categorical_accuracy: 0.5838
# Epoch 10/20
# 340/340 [==============================] - 61s 179ms/step - loss: 0.6483 - sparse_categorical_accuracy: 0.7546 - val_loss: 1.2192 - val_sparse_categorical_accuracy: 0.5993
# Epoch 11/20
# 340/340 [==============================] - 61s 178ms/step - loss: 0.6147 - sparse_categorical_accuracy: 0.7681 - val_loss: 1.3476 - val_sparse_categorical_accuracy: 0.6053
# Epoch 12/20
# 340/340 [==============================] - 60s 177ms/step - loss: 0.5733 - sparse_categorical_accuracy: 0.7785 - val_loss: 1.4094 - val_sparse_categorical_accuracy: 0.5976
# Epoch 13/20
# 340/340 [==============================] - 60s 176ms/step - loss: 0.5487 - sparse_categorical_accuracy: 0.7863 - val_loss: 1.3655 - val_sparse_categorical_accuracy: 0.5999
# Epoch 14/20
# 340/340 [==============================] - 59s 173ms/step - loss: 0.5382 - sparse_categorical_accuracy: 0.7956 - val_loss: 1.3893 - val_sparse_categorical_accuracy: 0.6110
# Epoch 15/20
# 340/340 [==============================] - 59s 174ms/step - loss: 0.5319 - sparse_categorical_accuracy: 0.8034 - val_loss: 1.4707 - val_sparse_categorical_accuracy: 0.5973
# Epoch 16/20
# 340/340 [==============================] - 60s 177ms/step - loss: 0.5266 - sparse_categorical_accuracy: 0.8049 - val_loss: 1.4976 - val_sparse_categorical_accuracy: 0.6023
# Epoch 17/20
# 340/340 [==============================] - 60s 176ms/step - loss: 0.5070 - sparse_categorical_accuracy: 0.8095 - val_loss: 1.5117 - val_sparse_categorical_accuracy: 0.6016
# Epoch 18/20
# 340/340 [==============================] - 59s 173ms/step - loss: 0.4982 - sparse_categorical_accuracy: 0.8140 - val_loss: 1.4650 - val_sparse_categorical_accuracy: 0.5962
# Epoch 19/20
# 340/340 [==============================] - 59s 174ms/step - loss: 0.4864 - sparse_categorical_accuracy: 0.8180 - val_loss: 1.4630 - val_sparse_categorical_accuracy: 0.5993
# Epoch 20/20
# 340/340 [==============================] - 60s 176ms/step - loss: 0.4906 - sparse_categorical_accuracy: 0.8147 - val_loss: 1.5078 - val_sparse_categorical_accuracy: 0.5915

# %%
graficar_historia_entrenamiento(r, metric='sparse_categorical_accuracy')

# %%
p = emo_model.predict(X_valid)
pred = np.argmax(p, axis=1)

# %%
Y_valid = Y_valid.astype(int)

# %%
emo_dict = {0: 'happy', 1: 'sad', 2: 'surprise', 3: 'fear', 4: 'disgust-contempt', 5: 'anger'}
emociones_1 = list(emo_dict.values())

CM_VGG = confusion_matrix(Y_valid, pred)
graf_confusion_matrix(CM_VGG, emociones_1 ,'VGG16')

# %%
m1 = calculo_metricas(CM_VGG, emociones_1)
m1
# Out:
#           Emociones  Accuracy  Precision    Recall  F1-Score
# 0             happy  0.877934   0.858300  0.710615  0.777506
# 1               sad  0.780013   0.497804  0.520674  0.508982
# 2          surprise  0.941650   0.861862  0.691566  0.767380
# 3              fear  0.795104   0.406504  0.504032  0.450045
# 4  disgust-contempt  0.981556   1.000000  0.017857  0.035088
# 5             anger  0.806841   0.410509  0.535332  0.464684

# %%
m1.mean()
# Out:
# Accuracy     0.863850
# Precision    0.672496
# Recall       0.496679
# F1-Score     0.500614
# dtype: float64

# %%
emo_model.save('top_VGG16_FER2013_emotions_v1.h5')
